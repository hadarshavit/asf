# %%
import pandas as pd

# %%
df = pd.read_csv(
    "/home/ni574034/asf/bench/results/results_MAXSAT12-PMS_per_instance.csv"
)
df
# Out:
#           scenario fold           selector  \
# 0     MAXSAT12-PMS    3   SingleBestSolver
# 1     MAXSAT12-PMS    3   SingleBestSolver
# 2     MAXSAT12-PMS    3   SingleBestSolver
# 3     MAXSAT12-PMS    3   SingleBestSolver
# 4     MAXSAT12-PMS    3   SingleBestSolver
# ...            ...  ...                ...
# 4903  MAXSAT12-PMS    1  PairwiseRegressor
# 4904  MAXSAT12-PMS    1  PairwiseRegressor
# 4905  MAXSAT12-PMS    1  PairwiseRegressor
# 4906  MAXSAT12-PMS    1  PairwiseRegressor
# 4907  MAXSAT12-PMS    1  PairwiseRegressor
#
#                                                instance  test_score
# 0     benchmarks/pms_crafted/frb/frb35-17-2.partial....      197.73
# 1     benchmarks/pms_crafted/frb/frb35-17-4.partial....      124.39
# 2     benchmarks/pms_crafted/frb/frb40-19-3.partial....    21000.00
# 3     benchmarks/pms_crafted/job-shop/la04-567-0696....        5.12
# 4     benchmarks/pms_crafted/maxclicque/random/max_c...        3.29
# ...

# %%
df.groupby(["scenario", "selector"]).mean(numeric_only=True)
# Out:
#                                     test_score
# scenario     selector
# MAXSAT12-PMS MultiClassClassifier  3624.567854
#              PairwiseClassifier    3267.617009
#              PairwiseRegressor     3346.354189
#              PerformanceModel      3366.327158
#              SingleBestSolver      5527.651749
#              VirtualBestSolver     3127.451107
# estSolver    456.6                         NaN
